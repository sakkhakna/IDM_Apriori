# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from apyori import apriori

# %%
# Load the market basket dataset
df = pd.read_excel('data/online_retail_II.xlsx')

# %%
# Display the first few rows
print("Dataset preview:")
print(df.head())
# Out:
# Dataset preview:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
# Data Cleaning Step
# Replace missing values with a placeholder (0 in this case)
df.fillna(0, inplace=True)
df.head()

# %%
# Verify column names
print("Columns in the DataFrame:", df.columns)

# Drop rows with missing values
df = df.dropna(subset=['Invoice', 'StockCode', 'Description'])  # Use the correct column names

# Remove credit transactions (those starting with 'C')
df = df[~df['Invoice'].astype(str).str.startswith('C')]

# Group by Invoice and aggregate items into a list
transactions = df.groupby('Invoice')['Description'].apply(list).values

# Convert transactions to a list of lists and remove duplicates
transaction_list = [list(set(transaction)) for transaction in transactions]
print("Total transactions:", len(transaction_list))
# Out:
# Columns in the DataFrame: Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')
# Total transactions: 21296

# %%
## verifying - by printing the 0th transaction
transactions[0]
# Out:
# ['15CM CHRISTMAS GLASS BALL 20 LIGHTS',
#  'PINK CHERRY LIGHTS',
#  ' WHITE CHERRY LIGHTS',
#  'RECORD FRAME 7" SINGLE SIZE ',
#  'STRAWBERRY CERAMIC TRINKET BOX',
#  'PINK DOUGHNUT TRINKET POT ',
#  'SAVE THE PLANET MUG',
#  'FANCY FONT HOME SWEET HOME DOORMAT']

# %%
## verifying - by printing the 1st transaction
transactions[1]
# Out:
# ['CAT BOWL ',
#  'DOG BOWL , CHASING BALL DESIGN',
#  'HEART MEASURING SPOONS LARGE',
#  'LUNCHBOX WITH CUTLERY FAIRY CAKES ']

# %%
# Convert transactions to a list of lists, remove duplicates, and ensure all items are strings
transaction_list = [[str(item) for item in set(transaction)] for transaction in transactions]

# %%
# Call apriori function which requires minimum support, confidance and lift, min length is combination of item default is 2".
rules = apriori(transaction_list, min_support=0.02, min_confidance=0.3, min_lift=1.0, min_length=2)

## min_support = 0.003 -> means selecting items with min support of 0.3%
## min_confidance = 0.2 -> means min confidance of 20% 
## min_lift = 3  
## min_length = 2 -> means no. of items in the transaction should be 2

# %%
#it generates a set of rules in a generator file...
rules
# Out:
# <generator object apriori at 0x00000221FFB48970>

# %%
# all rules need to be converted in a list..
Results = list(rules)
Results
# Out:
# [RelationRecord(items=frozenset({'12 PENCILS SMALL TUBE SKULL'}), support=0.02324380165289256, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'12 PENCILS SMALL TUBE SKULL'}), confidence=0.02324380165289256, lift=1.0)]),
#  RelationRecord(items=frozenset({'3 HEARTS HANGING DECORATION RUSTIC'}), support=0.021130728775356874, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'3 HEARTS HANGING DECORATION RUSTIC'}), confidence=0.021130728775356874, lift=1.0)]),
#  RelationRecord(items=frozenset({'6 RIBBONS RUSTIC CHARM'}), support=0.03925619834710744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'6 RIBBONS RUSTIC CHARM'}), confidence=0.03925619834710744, lift=1.0)]),
#  RelationRecord(items=frozenset({'60 CAKE CASES VINTAGE CHRISTMAS'}), support=0.022163786626596543, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'60 CAKE CASES VINTAGE CHRISTMAS'}), confidence=0.022163786626596543, lift=1.0)]),
#  RelationRecord(items=frozenset({'60 TEATIME FAIRY CAKE CASES'}), support=0.06273478587528174, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'60 TEATIME FAIRY CAKE CASES'}), confidence=0.06273478587528174, lift=1.0)]),
#  RelationRecord(items=frozenset({'72 SWEETHEART FAIRY CAKE CASES'}), support=0.04089969947407964, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'72 SWEETHEART FAIRY CAKE CASES'}), confidence=0.04089969947407964, lift=1.0)]),
#  RelationRecord(items=frozenset({'ANTIQUE SILVER TEA GLASS ETCHED'}), support=0.04259015777610819, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ANTIQUE SILVER TEA GLASS ETCHED'}), confidence=0.04259015777610819, lift=1.0)]),
#  RelationRecord(items=frozenset({'ASSORTED COLOUR BIRD ORNAMENT'}), support=0.06635048835462058, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ASSORTED COLOUR BIRD ORNAMENT'}), confidence=0.06635048835462058, lift=1.0)]),
#  RelationRecord(items=frozenset({'ASSORTED COLOURS SILK FAN'}), support=0.022774229902329076, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ASSORTED COLOURS SILK FAN'}), confidence=0.022774229902329076, lift=1.0)]),
#  RelationRecord(items=frozenset({'ASSTD DESIGN BUBBLE GUM RING'}), support=0.02235161532682194, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ASSTD DESIGN BUBBLE GUM RING'}), confidence=0.02235161532682194, lift=1.0)]),
#  RelationRecord(items=frozenset({'BAKING SET 9 PIECE RETROSPOT '}), support=0.04601803155522164, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'BAKING SET 9 PIECE RETROSPOT '}), confidence=0.04601803155522164, lift=1.0)]),
#  RelationRecord(items=frozenset({'BAKING SET SPACEBOY DESIGN'}), support=0.023149887302779865, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'BAKING SET SPACEBOY DESIGN'}), confidence=0.023149887302779865, lift=1.0)]),
#  RelationRecord(items=frozenset({'BATHROOM METAL SIGN'}), support=0.034372652141247184, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'BATHROOM METAL SIGN'}), confidence=0.034372652141247184, lift=1.0)]),
#  RelationRecord(items=frozenset({'BEWARE OF THE CAT METAL SIGN '}), support=0.0253099173553719, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'BEWARE OF THE CAT METAL SIGN '}), confidence=0.0253099173553719, lift=1.0)]),
#  RelationRecord(items=frozenset({'BINGO SET'}), support=0.02225770097670924, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'BINGO SET'}), confidence=0.02225770097670924, lift=1.0)]),
#  RelationRecord(items=frozenset({'BLUE 3 PIECE MINI DOTS CUTLERY SET'}), support=0.022445529676934636, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'BLUE 3 PIECE MINI DOTS CUTLERY SET'}), confidence=0.022445529676934636, lift=1.0)]),
#  RelationRecord(items=frozenset({'BOX OF 24 COCKTAIL PARASOLS'}), support=0.026859504132231406, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'BOX OF 24 COCKTAIL PARASOLS'}), confidence=0.026859504132231406, lift=1.0)]),
#  RelationRecord(items=frozenset({'CERAMIC STRAWBERRY CAKE MONEY BANK'}), support=0.02437077385424493, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CERAMIC STRAWBERRY CAKE MONEY BANK'}), confidence=0.02437077385424493, lift=1.0)]),
#  RelationRecord(items=frozenset({'CHARLOTTE BAG SUKI DESIGN'}), support=0.025826446280991736, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CHARLOTTE BAG SUKI DESIGN'}), confidence=0.025826446280991736, lift=1.0)]),
#  RelationRecord(items=frozenset({'CHICK GREY HOT WATER BOTTLE'}), support=0.02361945905334335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CHICK GREY HOT WATER BOTTLE'}), confidence=0.02361945905334335, lift=1.0)]),
#  RelationRecord(items=frozenset({'CHILLI LIGHTS'}), support=0.024182945154019534, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CHILLI LIGHTS'}), confidence=0.024182945154019534, lift=1.0)]),
#  RelationRecord(items=frozenset({'CHOCOLATE HOT WATER BOTTLE'}), support=0.04357625845229151, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CHOCOLATE HOT WATER BOTTLE'}), confidence=0.04357625845229151, lift=1.0)]),
#  RelationRecord(items=frozenset({'CHOCOLATE THIS WAY METAL SIGN'}), support=0.02474643125469572, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CHOCOLATE THIS WAY METAL SIGN'}), confidence=0.02474643125469572, lift=1.0)]),
#  RelationRecord(items=frozenset({'CLOTHES PEGS RETROSPOT PACK 24 '}), support=0.021741172051089407, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CLOTHES PEGS RETROSPOT PACK 24 '}), confidence=0.021741172051089407, lift=1.0)]),
#  RelationRecord(items=frozenset({'COLOUR GLASS T-LIGHT HOLDER HANGING'}), support=0.030522163786626595, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'COLOUR GLASS T-LIGHT HOLDER HANGING'}), confidence=0.030522163786626595, lift=1.0)]),
#  RelationRecord(items=frozenset({'COLOUR GLASS. STAR T-LIGHT HOLDER'}), support=0.024558602554470323, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'COLOUR GLASS. STAR T-LIGHT HOLDER'}), confidence=0.024558602554470323, lift=1.0)]),
#  RelationRecord(items=frozenset({'COOK WITH WINE METAL SIGN '}), support=0.034372652141247184, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'COOK WITH WINE METAL SIGN '}), confidence=0.034372652141247184, lift=1.0)]),
#  RelationRecord(items=frozenset({'CREAM CUPID HEARTS COAT HANGER'}), support=0.02779864763335838, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CREAM CUPID HEARTS COAT HANGER'}), confidence=0.02779864763335838, lift=1.0)]),
#  RelationRecord(items=frozenset({'CREAM HEART CARD HOLDER'}), support=0.037424868519909844, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CREAM HEART CARD HOLDER'}), confidence=0.037424868519909844, lift=1.0)]),
#  RelationRecord(items=frozenset({'CREAM SWEETHEART MINI CHEST'}), support=0.020003756574004508, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CREAM SWEETHEART MINI CHEST'}), confidence=0.020003756574004508, lift=1.0)]),
#  RelationRecord(items=frozenset({'DOLLY GIRL LUNCH BOX'}), support=0.024182945154019534, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'DOLLY GIRL LUNCH BOX'}), confidence=0.024182945154019534, lift=1.0)]),
#  RelationRecord(items=frozenset({'DOOR MAT NEW ENGLAND'}), support=0.021788129226145755, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'DOOR MAT NEW ENGLAND'}), confidence=0.021788129226145755, lift=1.0)]),
#  RelationRecord(items=frozenset({'DOOR MAT UNION FLAG'}), support=0.031649135987978964, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'DOOR MAT UNION FLAG'}), confidence=0.031649135987978964, lift=1.0)]),
#  RelationRecord(items=frozenset({'DOORMAT HEARTS'}), support=0.02164725770097671, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'DOORMAT HEARTS'}), confidence=0.02164725770097671, lift=1.0)]),
#  RelationRecord(items=frozenset({'DOTCOM POSTAGE'}), support=0.03441960931630353, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'DOTCOM POSTAGE'}), confidence=0.03441960931630353, lift=1.0)]),
#  RelationRecord(items=frozenset({'EDWARDIAN PARASOL BLACK'}), support=0.027422990232907587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'EDWARDIAN PARASOL BLACK'}), confidence=0.027422990232907587, lift=1.0)]),
#  RelationRecord(items=frozenset({'EDWARDIAN PARASOL NATURAL'}), support=0.029489105935386926, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'EDWARDIAN PARASOL NATURAL'}), confidence=0.029489105935386926, lift=1.0)]),
#  RelationRecord(items=frozenset({'FAWN BLUE HOT WATER BOTTLE'}), support=0.028925619834710745, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FAWN BLUE HOT WATER BOTTLE'}), confidence=0.028925619834710745, lift=1.0)]),
#  RelationRecord(items=frozenset({'FELTCRAFT 6 FLOWER FRIENDS'}), support=0.04089969947407964, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELTCRAFT 6 FLOWER FRIENDS'}), confidence=0.04089969947407964, lift=1.0)]),
#  RelationRecord(items=frozenset({'FELTCRAFT BUTTERFLY HEARTS'}), support=0.03240045078888054, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELTCRAFT BUTTERFLY HEARTS'}), confidence=0.03240045078888054, lift=1.0)]),
#  RelationRecord(items=frozenset({'FELTCRAFT CUSHION BUTTERFLY'}), support=0.022445529676934636, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELTCRAFT CUSHION BUTTERFLY'}), confidence=0.022445529676934636, lift=1.0)]),
#  RelationRecord(items=frozenset({'FELTCRAFT CUSHION OWL'}), support=0.02094290007513148, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELTCRAFT CUSHION OWL'}), confidence=0.02094290007513148, lift=1.0)]),
#  RelationRecord(items=frozenset({'FELTCRAFT CUSHION RABBIT'}), support=0.02169421487603306, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELTCRAFT CUSHION RABBIT'}), confidence=0.02169421487603306, lift=1.0)]),
#  RelationRecord(items=frozenset({'FELTCRAFT DOLL MOLLY'}), support=0.023196844477836213, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELTCRAFT DOLL MOLLY'}), confidence=0.023196844477836213, lift=1.0)]),
#  RelationRecord(items=frozenset({'FELTCRAFT DOLL ROSIE'}), support=0.023525544703230653, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FELTCRAFT DOLL ROSIE'}), confidence=0.023525544703230653, lift=1.0)]),
#  RelationRecord(items=frozenset({'FOUR HOOK  WHITE LOVEBIRDS'}), support=0.02098985725018783, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'FOUR HOOK  WHITE LOVEBIRDS'}), confidence=0.02098985725018783, lift=1.0)]),
#  RelationRecord(items=frozenset({'GARDENERS KNEELING PAD'}), support=0.02601427498121713, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'GARDENERS KNEELING PAD'}), confidence=0.02601427498121713, lift=1.0)]),
#  RelationRecord(items=frozenset({'GIN + TONIC DIET METAL SIGN'}), support=0.04132231404958678, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'GIN + TONIC DIET METAL SIGN'}), confidence=0.04132231404958678, lift=1.0)]),
#  RelationRecord(items=frozenset({'GRAND CHOCOLATECANDLE'}), support=0.030663035311795643, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'GRAND CHOCOLATECANDLE'}), confidence=0.030663035311795643, lift=1.0)]),
#  RelationRecord(items=frozenset({'GREY HEART HOT WATER BOTTLE'}), support=0.02263335837716003, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'GREY HEART HOT WATER BOTTLE'}), confidence=0.02263335837716003, lift=1.0)]),
#  RelationRecord(items=frozenset({'GUMBALL COAT RACK'}), support=0.020802028549962433, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'GUMBALL COAT RACK'}), confidence=0.020802028549962433, lift=1.0)]),
#  RelationRecord(items=frozenset({'HAND OVER THE CHOCOLATE   SIGN '}), support=0.038223140495867766, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HAND OVER THE CHOCOLATE   SIGN '}), confidence=0.038223140495867766, lift=1.0)]),
#  RelationRecord(items=frozenset({'HAND WARMER BIRD DESIGN'}), support=0.028268219383921864, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HAND WARMER BIRD DESIGN'}), confidence=0.028268219383921864, lift=1.0)]),
#  RelationRecord(items=frozenset({'HAND WARMER OWL DESIGN'}), support=0.029770848985725018, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HAND WARMER OWL DESIGN'}), confidence=0.029770848985725018, lift=1.0)]),
#  RelationRecord(items=frozenset({'HAND WARMER RED RETROSPOT'}), support=0.020050713749060856, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HAND WARMER RED RETROSPOT'}), confidence=0.020050713749060856, lift=1.0)]),
#  RelationRecord(items=frozenset({'HAND WARMER SCOTTY DOG DESIGN'}), support=0.028784748309541697, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HAND WARMER SCOTTY DOG DESIGN'}), confidence=0.028784748309541697, lift=1.0)]),
#  RelationRecord(items=frozenset({'HAND WARMER UNION JACK'}), support=0.02197595792637115, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HAND WARMER UNION JACK'}), confidence=0.02197595792637115, lift=1.0)]),
#  RelationRecord(items=frozenset({'HANGING HEART JAR T-LIGHT HOLDER'}), support=0.03319872276483847, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'
ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PAPER BUNTING RETRO SPOTS'}), confidence=0.036767468069120963, lift=1.0)]),
#  RelationRecord(items=frozenset({'PAPER BUNTING WHITE LACE'}), support=0.02493425995492111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PAPER BUNTING WHITE LACE'}), confidence=0.02493425995492111, lift=1.0)]),
#  RelationRecord(items=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS "}), support=0.04493801652892562, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS "}), confidence=0.04493801652892562, lift=1.0)]),
#  RelationRecord(items=frozenset({'PAPER CHAIN KIT RETRO SPOT'}), support=0.027751690458302027, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PAPER CHAIN KIT RETRO SPOT'}), confidence=0.027751690458302027, lift=1.0)]),
#  RelationRecord(items=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS'}), support=0.03235349361382419, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS'}), confidence=0.03235349361382419, lift=1.0)]),
#  RelationRecord(items=frozenset({'PARTY BUNTING'}), support=0.04761457550713749, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PARTY BUNTING'}), confidence=0.04761457550713749, lift=1.0)]),
#  RelationRecord(items=frozenset({'PARTY METAL SIGN '}), support=0.023995116453794138, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PARTY METAL SIGN '}), confidence=0.023995116453794138, lift=1.0)]),
#  RelationRecord(items=frozenset({'PICNIC BASKET WICKER SMALL'}), support=0.02300901577761082, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PICNIC BASKET WICKER SMALL'}), confidence=0.02300901577761082, lift=1.0)]),
#  RelationRecord(items=frozenset({'PINK 3 PIECE MINI DOTS CUTLERY SET'}), support=0.021036814425244178, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PINK 3 PIECE MINI DOTS CUTLERY SET'}), confidence=0.021036814425244178, lift=1.0)]),
#  RelationRecord(items=frozenset({'PINK BLUE FELT CRAFT TRINKET BOX'}), support=0.030803906836964687, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PINK BLUE FELT CRAFT TRINKET BOX'}), confidence=0.030803906836964687, lift=1.0)]),
#  RelationRecord(items=frozenset({'PINK CREAM FELT CRAFT TRINKET BOX '}), support=0.03827009767092412, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PINK CREAM FELT CRAFT TRINKET BOX '}), confidence=0.03827009767092412, lift=1.0)]),
#  RelationRecord(items=frozenset({'PINK DOUGHNUT TRINKET POT '}), support=0.021835086401202103, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PINK DOUGHNUT TRINKET POT '}), confidence=0.021835086401202103, lift=1.0)]),
#  RelationRecord(items=frozenset({'PINK HAPPY BIRTHDAY BUNTING'}), support=0.022868144252441772, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PINK HAPPY BIRTHDAY BUNTING'}), confidence=0.022868144252441772, lift=1.0)]),
#  RelationRecord(items=frozenset({'PINK HEART SHAPE EGG FRYING PAN'}), support=0.02258640120210368, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PINK HEART SHAPE EGG FRYING PAN'}), confidence=0.02258640120210368, lift=1.0)]),
#  RelationRecord(items=frozenset({'PLASTERS IN TIN CIRCUS PARADE '}), support=0.030616078136739295, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PLASTERS IN TIN CIRCUS PARADE '}), confidence=0.030616078136739295, lift=1.0)]),
#  RelationRecord(items=frozenset({'PLASTERS IN TIN SKULLS'}), support=0.026718632607062358, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PLASTERS IN TIN SKULLS'}), confidence=0.026718632607062358, lift=1.0)]),
#  RelationRecord(items=frozenset({'PLASTERS IN TIN SPACEBOY'}), support=0.031320435762584524, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PLASTERS IN TIN SPACEBOY'}), confidence=0.031320435762584524, lift=1.0)]),
#  RelationRecord(items=frozenset({'PLASTERS IN TIN STRONGMAN'}), support=0.021835086401202103, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PLASTERS IN TIN STRONGMAN'}), confidence=0.021835086401202103, lift=1.0)]),
#  RelationRecord(items=frozenset({'PLASTERS IN TIN VINTAGE PAISLEY '}), support=0.027939519158527423, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PLASTERS IN TIN VINTAGE PAISLEY '}), confidence=0.027939519158527423, lift=1.0)]),
#  RelationRecord(items=frozenset({'P
ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'RED WOOLLY HOTTIE WHITE HEART.'}), confidence=0.03780052592036063, lift=1.0)]),
#  RelationRecord(items=frozenset({'REGENCY CAKESTAND 3 TIER'}), support=0.0948534936138242, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'REGENCY CAKESTAND 3 TIER'}), confidence=0.0948534936138242, lift=1.0)]),
#  RelationRecord(items=frozenset({'RETRO SPOT LARGE MILK JUG'}), support=0.02437077385424493, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'RETRO SPOT LARGE MILK JUG'}), confidence=0.02437077385424493, lift=1.0)]),
#  RelationRecord(items=frozenset({'RETRO SPOT TEA SET CERAMIC 11 PC '}), support=0.03620398196844478, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'RETRO SPOT TEA SET CERAMIC 11 PC '}), confidence=0.03620398196844478, lift=1.0)]),
#  RelationRecord(items=frozenset({'REX CASH+CARRY JUMBO SHOPPER'}), support=0.05047896318557476, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'REX CASH+CARRY JUMBO SHOPPER'}), confidence=0.05047896318557476, lift=1.0)]),
#  RelationRecord(items=frozenset({'RIBBON REEL STRIPES DESIGN '}), support=0.027141247182569498, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'RIBBON REEL STRIPES DESIGN '}), confidence=0.027141247182569498, lift=1.0)]),
#  RelationRecord(items=frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS '}), support=0.02803343350864012, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS '}), confidence=0.02803343350864012, lift=1.0)]),
#  RelationRecord(items=frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND '}), support=0.0320717505634861, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND '}), confidence=0.0320717505634861, lift=1.0)]),
#  RelationRecord(items=frozenset({'SAVE THE PLANET MUG'}), support=0.021177685950413222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SAVE THE PLANET MUG'}), confidence=0.021177685950413222, lift=1.0)]),
#  RelationRecord(items=frozenset({'SCANDINAVIAN REDS RIBBONS'}), support=0.02225770097670924, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SCANDINAVIAN REDS RIBBONS'}), confidence=0.02225770097670924, lift=1.0)]),
#  RelationRecord(items=frozenset({'SCOTTIE DOG HOT WATER BOTTLE'}), support=0.04667543200601052, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SCOTTIE DOG HOT WATER BOTTLE'}), confidence=0.04667543200601052, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET 12 KIDS COLOUR  CHALK STICKS'}), support=0.02061419984973704, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET 12 KIDS COLOUR  CHALK STICKS'}), confidence=0.02061419984973704, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET OF 20 VINTAGE CHRISTMAS NAPKINS'}), support=0.02493425995492111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET OF 20 VINTAGE CHRISTMAS NAPKINS'}), confidence=0.02493425995492111, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET OF 3 BUTTERFLY COOKIE CUTTERS'}), support=0.021083771600300526, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET OF 3 BUTTERFLY COOKIE CUTTERS'}), confidence=0.021083771600300526, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET OF 3 HEART COOKIE CUTTERS'}), support=0.027751690458302027, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET OF 3 HEART COOKIE CUTTERS'}), confidence=0.027751690458302027, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET OF 36 PAISLEY FLOWER DOILIES'}), support=0.02131855747558227, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET OF 36 PAISLEY FLOWER DOILIES'}), confidence=0.02131855747558227, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET OF 36 TEATIME PAPER DOILIES'}), support=0.022868144252441772, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET OF 36 TEATIME PAPER DOILIES'}), confidence=0.022868144252441772, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET OF 72 PINK HEART PAPER DOILIES'}), support=0.024511645379413975, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET OF 72 PINK HEART PAPER DOILIES'}), confidence=0.024511645379413975, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET OF 72 RETRO SPOT PAPER  DOILIES'}), support=0.02601427498121713, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET OF 72 RETRO SPOT PAPER  DOILIES'}), confidence=0.02601427498121713, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET/2 RED SPOTTY TEA TOWELS '}), support=0.020003756574004508, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET/2 RED SPOTTY TEA TOWELS '}), confidence=0.020003756574004508, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET/20 RED SPOTTY PAPER NAPKINS '}), support=0.04423365890308039, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET/20 RED SPOTTY PAPER NAPKINS '}), confidence=0.04423365890308039, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET/20 STRAWBERRY PAPER NAPKINS '}), support=0.020379413974455297, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET/20 STRAWBERRY PAPER NAPKINS '}), confidence=0.020379413974455297, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET/5 RED SPOTTY LID GLASS BOWLS'}), support=0.041463185574755826, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET/5 RED SPOTTY LID GLASS BOWLS'}), confidence=0.041463185574755826, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET/6 RED SPOTTY PAPER CUPS'}), support=0.0201915852742299, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET/6 RED SPOTTY PAPER CUPS'}), confidence=0.0201915852742299, lift=1.0)]),
#  RelationRecord(items=frozenset({'SET/6 RED SPOTTY PAPER PLATES'}), support=0.02221074380165289, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SET/6 RED SPOTTY PAPER PLATES'}), confidence=0.02221074380165289, lift=1.0)]),
#  RelationRecord(items=frozenset({'SINGLE HEART ZINC T-LIGHT HOLDER'}), support=0.031179564237415476, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SINGLE HEART ZINC T-LIGHT HOLDER'}), confidence=0.031179564237415476, lift=1.0)]),
#  RelationRecord(items=frozenset({'SMALL GLASS HEART TRINKET POT'}), support=0.025591660405709992, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SMALL GLASS HEART TRINKET POT'}), confidence=0.025591660405709992, lift=1.0)]),
#  RelationRecord(items=frozenset({'SMALL HEART MEASURING SPOONS'}), support=0.02507513148009016, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'SMALL HEART MEASURING SPOONS'}), confidence=0.02507513148009016, lift=1.0)]),
# ...
#  RelationRecord(items=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES', '60 TEATIME FAIRY CAKE CASES'}), support=0.027845604808414727, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES', '60 TEATIME FAIRY CAKE CASES'}), confidence=0.027845604808414727, lift=1.0), OrderedStatistic(items_base=frozenset({'60 TEATIME FAIRY CAKE CASES'}), items_add=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES'}), confidence=0.44386227544910184, lift=8.183974907328201), OrderedStatistic(items_base=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES'}), items_add=frozenset({'60 TEATIME FAIRY CAKE CASES'}), confidence=0.5134199134199134, lift=8.183974907328201)]),
#  RelationRecord(items=frozenset({'60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'}), support=0.028315176558978212, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'}), confidence=0.028315176558978212, lift=1.0), OrderedStatistic(items_base=frozenset({'60 TEATIME FAIRY CAKE CASES'}), items_add=frozenset({'PACK OF 72 RETRO SPOT CAKE CASES'}), confidence=0.4513473053892216, lift=6.816944833736783), OrderedStatistic(items_base=frozenset({'PACK OF 72 RETRO SPOT CAKE CASES'}), items_add=frozenset({'60 TEATIME FAIRY CAKE CASES'}), confidence=0.42765957446808517, lift=6.816944833736783)]),
#  RelationRecord(items=frozenset({'ASSORTED COLOUR BIRD ORNAMENT', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.020708114199849737, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ASSORTED COLOUR BIRD ORNAMENT', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.020708114199849737, lift=1.0), OrderedStatistic(items_base=frozenset({'ASSORTED COLOUR BIRD ORNAMENT'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.3121019108280255, lift=2.0043794610957875), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'ASSORTED COLOUR BIRD ORNAMENT'}), confidence=0.1329915560916767, lift=2.004379461095787)]),
#  RelationRecord(items=frozenset({'CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY'}), support=0.022492486851990984, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY'}), confidence=0.022492486851990984, lift=1.0), OrderedStatistic(items_base=frozenset({'CHOCOLATE HOT WATER BOTTLE'}), items_add=frozenset({'HOT WATER BOTTLE TEA AND SYMPATHY'}), confidence=0.5161637931034483, lift=10.819118245995114), OrderedStatistic(items_base=frozenset({'HOT WATER BOTTLE TEA AND SYMPATHY'}), items_add=frozenset({'CHOCOLATE HOT WATER BOTTLE'}), confidence=0.4714566929133858, lift=10.819118245995114)]),
#  RelationRecord(items=frozenset({'HEART OF WICKER SMALL', 'HEART OF WICKER LARGE'}), support=0.025873403456048084, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HEART OF WICKER SMALL', 'HEART OF WICKER LARGE'}), confidence=0.025873403456048084, lift=1.0), OrderedStatistic(items_base=frozenset({'HEART OF WICKER LARGE'}), items_add=frozenset({'HEART OF WICKER SMALL'}), confidence=0.5027372262773723, lift=10.404559738389622), OrderedStatistic(items_base=frozenset({'HEART OF WICKER SMALL'}), items_add=frozenset({'HEART OF WICKER LARGE'}), confidence=0.5354713313896988, lift=10.404559738389622)]),
#  RelationRecord(items=frozenset({'HEART OF WICKER LARGE', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.020379413974455297, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HEART OF WICKER LARGE', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.020379413974455297, lift=1.0), OrderedStatistic(items_base=frozenset({'HEART OF WICKER LARGE'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.395985401459854, lift=2.5430956301233567), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'HEART OF WICKER LARGE'}), confidence=0.13088057901085645, lift=2.5430956301233567)]),
#  RelationRecord(items=frozenset({'HOME BUILDING BLOCK WORD', 'LOVE BUILDING BLOCK WORD'}), support=0.02746994740796394, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HOME BUILDING BLOCK WORD', 'LOVE BUILDING BLOCK WORD'}), confidence=0.02746994740796394, lift=1.0), OrderedStatistic(items_base=frozenset({'HOME BUILDING BLOCK WORD'}), items_add=frozenset({'LOVE BUILDING BLOCK WORD'}), confidence=0.439519158527423, lift=8.57928505957837), OrderedStatistic(items_base=frozenset({'LOVE BUILDING BLOCK WORD'}), items_add=frozenset({'HOME BUILDING BLOCK WORD'}), confidence=0.5362053162236481, lift=8.57928505957837)]),
#  RelationRecord(items=frozenset({'HOME BUILDING BLOCK WORD', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.02371337340345605, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'HOME BUILDING BLOCK WORD', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.02371337340345605, lift=1.0), OrderedStatistic(items_base=frozenset({'HOME BUILDING BLOCK WORD'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.3794139744552968, lift=2.436670687575392), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'HOME BUILDING BLOCK WORD'}), confidence=0.152291917973462, lift=2.436670687575392)]),
#  RelationRecord(items=frozenset({'JUMBO BAG STRAWBERRY', 'JUMBO STORAGE BAG SUKI'}), support=0.021271600300525922, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'JUMBO BAG STRAWBERRY', 'JUMBO STORAGE BAG SUKI'}), confidence=0.021271600300525922, lift=1.0), OrderedStatistic(items_base=frozenset({'JUMBO BAG STRAWBERRY'}), items_add=frozenset({'JUMBO STORAGE BAG SUKI'}), confidence=0.4285714285714286, lift=7.734624697336563), OrderedStatistic(items_base=frozenset({'JUMBO STORAGE BAG SUKI'}), items_add=frozenset({'JUMBO BAG STRAWBERRY'}), confidence=0.3838983050847458, lift=7.734624697336563)]),
#  RelationRecord(items=frozenset({'LOVE BUILDING BLOCK WORD', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.021600300525920362, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LOVE BUILDING BLOCK WORD', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.021600300525920362, lift=1.0), OrderedStatistic(items_base=frozenset({'LOVE BUILDING BLOCK WORD'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.4216315307057745, lift=2.7078000838088583), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'LOVE BUILDING BLOCK WORD'}), confidence=0.13872135102533173, lift=2.7078000838088583)]),
#  RelationRecord(items=frozenset({'LUNCH BAG RED SPOTTY', 'LUNCH BAG  BLACK SKULL.'}), support=0.021083771600300526, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED SPOTTY'}), confidence=0.021083771600300526, lift=1.0), OrderedStatistic(items_base=frozenset({'LUNCH BAG  BLACK SKULL.'}), items_add=frozenset({'LUNCH BAG RED SPOTTY'}), confidence=0.4026905829596413, lift=7.040803493192546), OrderedStatistic(items_base=frozenset({'LUNCH BAG RED SPOTTY'}), items_add=frozenset({'LUNCH BAG  BLACK SKULL.'}), confidence=0.36863711001642036, lift=7.040803493192546)]),
#  RelationRecord(items=frozenset({'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI  DESIGN '}), support=0.020379413974455297, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG SUKI  DESIGN '}), confidence=0.020379413974455297, lift=1.0), OrderedStatistic(items_base=frozenset({'LUNCH BAG  BLACK SKULL.'}), items_add=frozenset({'LUNCH BAG SUKI  DESIGN '}), confidence=0.389237668161435, lift=7.440938403201005), OrderedStatistic(items_base=frozenset({'LUNCH BAG SUKI  DESIGN '}), items_add=frozenset({'LUNCH BAG  BLACK SKULL.'}), confidence=0.3895870736086176, lift=7.440938403201005)]),
#  RelationRecord(items=frozenset({'LUNCH BAG RED SPOTTY', 'LUNCH BAG PINK RETROSPOT'}), support=0.020238542449286252, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LUNCH BAG RED SPOTTY', 'LUNCH BAG PINK RETROSPOT'}), confidence=0.020238542449286252, lift=1.0), OrderedStatistic(items_base=frozenset({'LUNCH BAG PINK RETROSPOT'}), items_add=frozenset({'LUNCH BAG RED SPOTTY'}), confidence=0.5307881773399016, lift=9.28051315651112), OrderedStatistic(items_base=frozenset({'LUNCH BAG RED SPOTTY'}), items_add=frozenset({'LUNCH BAG PINK RETROSPOT'}), confidence=0.35385878489326766, lift=9.28051315651112)]),
#  RelationRecord(items=frozenset({'LUNCH BAG SUKI  DESIGN ', 'LUNCH BAG SPACEBOY DESIGN '}), support=0.022868144252441772, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'LUNCH BAG SUKI  DESIGN ', 'LUNCH BAG SPACEBOY DESIGN '}), confidence=0.022868144252441772, lift=1.0), OrderedStatistic(items_base=frozenset({'LUNCH BAG SPACEBOY DESIGN '}), items_add=frozenset({'LUNCH BAG SUKI  DESIGN '}), confidence=0.4964322120285423, lift=9.490143974290698), OrderedStatistic(items_base=frozenset({'LUNCH BAG SUKI  DESIGN '}), items_add=frozenset({'LUNCH BAG SPACEBOY DESIGN '}), confidence=0.4371633752244165, lift=9.490143974290698)]),
#  RelationRecord(items=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'}), support=0.02507513148009016, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES', 'PACK OF 72 RETRO SPOT CAKE CASES'}), confidence=0.02507513148009016, lift=1.0), OrderedStatistic(items_base=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES'}), items_add=frozenset({'PACK OF 72 RETRO SPOT CAKE CASES'}), confidence=0.4623376623376624, lift=6.982938196555219), OrderedStatistic(items_base=frozenset({'PACK OF 72 RETRO SPOT CAKE CASES'}), items_add=frozenset({'PACK OF 60 PINK PAISLEY CAKE CASES'}), confidence=0.3787234042553192, lift=6.982938196555219)]),
#  RelationRecord(items=frozenset({'RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.03620398196844478, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'RED HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.03620398196844478, lift=1.0), OrderedStatistic(items_base=frozenset({'RED HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.7232645403377111, lift=4.644946215630849), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'RED HANGING HEART T-LIGHT HOLDER'}), confidence=0.23250904704463207, lift=4.644946215630849)]),
#  RelationRecord(items=frozenset({'REGENCY CAKESTAND 3 TIER', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.020144628099173553, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'REGENCY CAKESTAND 3 TIER', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.020144628099173553, lift=1.0), OrderedStatistic(items_base=frozenset({'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.21237623762376234, lift=1.3639216997694943), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'REGENCY CAKESTAND 3 TIER'}), confidence=0.12937273823884196, lift=1.3639216997694943)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CERAMIC TRINKET BOX', 'SWEETHEART CERAMIC TRINKET BOX'}), support=0.03737791134485349, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'STRAWBERRY CERAMIC TRINKET BOX', 'SWEETHEART CERAMIC TRINKET BOX'}), confidence=0.03737791134485349, lift=1.0), OrderedStatistic(items_base=frozenset({'STRAWBERRY CERAMIC TRINKET BOX'}), items_add=frozenset({'SWEETHEART CERAMIC TRINKET BOX'}), confidence=0.4853658536585366, lift=10.326025194317877), OrderedStatistic(items_base=frozenset({'SWEETHEART CERAMIC TRINKET BOX'}), items_add=frozenset({'STRAWBERRY CERAMIC TRINKET BOX'}), confidence=0.7952047952047951, lift=10.326025194317875)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CERAMIC TRINKET BOX', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.025216003005259204, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'STRAWBERRY CERAMIC TRINKET BOX', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.025216003005259204, lift=1.0), OrderedStatistic(items_base=frozenset({'STRAWBERRY CERAMIC TRINKET BOX'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.32743902439024386, lift=2.1028774015122536), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'STRAWBERRY CERAMIC TRINKET BOX'}), confidence=0.16194209891435463, lift=2.1028774015122536)]),
#  RelationRecord(items=frozenset({'VINTAGE SNAP CARDS', 'VINTAGE HEADS AND TAILS CARD GAME '}), support=0.02084898572501878, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'VINTAGE SNAP CARDS', 'VINTAGE HEADS AND TAILS CARD GAME '}), confidence=0.02084898572501878, lift=1.0), OrderedStatistic(items_base=frozenset({'VINTAGE HEADS AND TAILS CARD GAME '}), items_add=frozenset({'VINTAGE SNAP CARDS'}), confidence=0.5951742627345844, lift=12.662168930265443), OrderedStatistic(items_base=frozenset({'VINTAGE SNAP CARDS'}), items_add=frozenset({'VINTAGE HEADS AND TAILS CARD GAME '}), confidence=0.4435564435564435, lift=12.662168930265443)]),
#  RelationRecord(items=frozenset({'WOODEN FRAME ANTIQUE WHITE ', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.02498121712997746, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'WOODEN FRAME ANTIQUE WHITE ', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.02498121712997746, lift=1.0), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'WOODEN FRAME ANTIQUE WHITE '}), confidence=0.16043425814234016, lift=2.9970245275432243), OrderedStatistic(items_base=frozenset({'WOODEN FRAME ANTIQUE WHITE '}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.4666666666666666, lift=2.9970245275432243)]),
#  RelationRecord(items=frozenset({'WOODEN PICTURE FRAME WHITE FINISH', 'WHITE HANGING HEART T-LIGHT HOLDER'}), support=0.021459429000751314, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'WOODEN PICTURE FRAME WHITE FINISH', 'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.021459429000751314, lift=1.0), OrderedStatistic(items_base=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'WOODEN PICTURE FRAME WHITE FINISH'}), confidence=0.13781664656212303, lift=3.099200955846855), OrderedStatistic(items_base=frozenset({'WOODEN PICTURE FRAME WHITE FINISH'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.4825765575501584, lift=3.0992009558468556)]),
#  RelationRecord(items=frozenset({'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE '}), support=0.028409090909090908, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE '}), confidence=0.028409090909090908, lift=1.0), OrderedStatistic(items_base=frozenset({'WOODEN FRAME ANTIQUE WHITE '}), items_add=frozenset({'WOODEN PICTURE FRAME WHITE FINISH'}), confidence=0.5307017543859649, lift=11.934344837807295), OrderedStatistic(items_base=frozenset({'WOODEN PICTURE FRAME WHITE FINISH'}), items_add=frozenset({'WOODEN FRAME ANTIQUE WHITE '}), confidence=0.6388595564941921, lift=11.934344837807293)])]

# %%
# convert result in a dataframe for further operation...
df_results = pd.DataFrame(Results)

# %%
# as we see "order_statistics" , is itself a list so need to be converted in proper format..
df_results.head()
# Out:
#                                   items   support  \
# 0         (12 PENCILS SMALL TUBE SKULL)  0.023244
# 1  (3 HEARTS HANGING DECORATION RUSTIC)  0.021131
# 2              (6 RIBBONS RUSTIC CHARM)  0.039256
# 3     (60 CAKE CASES VINTAGE CHRISTMAS)  0.022164
# 4         (60 TEATIME FAIRY CAKE CASES)  0.062735
#
#                                   ordered_statistics
# 0  [((), (12 PENCILS SMALL TUBE SKULL), 0.0232438...
# 1  [((), (3 HEARTS HANGING DECORATION RUSTIC), 0....
# 2  [((), (6 RIBBONS RUSTIC CHARM), 0.039256198347...
# 3  [((), (60 CAKE CASES VINTAGE CHRISTMAS), 0.022...
# 4  [((), (60 TEATIME FAIRY CAKE CASES), 0.0627347...

# %%
# keep support in a separate data frame so we can use later.. 
support = df_results.support

# %%
#all four empty list which will contain lhs, rhs, confidance and lift respectively.
first_values = []
second_values = []
third_values = []
fourth_value = []

# loop number of rows time and append 1 by 1 value in a separate list.. 
# first and second element was frozenset which need to be converted in list..
for i in range(df_results.shape[0]):
    single_list = df_results['ordered_statistics'][i][0]
    first_values.append(list(single_list[0]))
    second_values.append(list(single_list[1]))
    third_values.append(single_list[2])
    fourth_value.append(single_list[3])

# %%
# convert all four list into dataframe for further operation..
lhs = pd.DataFrame(first_values)
rhs = pd.DataFrame(second_values)

confidance=pd.DataFrame(third_values,columns=['Confidance'])

lift=pd.DataFrame(fourth_value,columns=['lift'])

# %%
# concat all list together in a single dataframe
df_final = pd.concat([lhs,rhs,support,confidance,lift], axis=1)
df_final
# Out:
#                                       0                                   1  \
# 0           12 PENCILS SMALL TUBE SKULL                                None
# 1    3 HEARTS HANGING DECORATION RUSTIC                                None
# 2                6 RIBBONS RUSTIC CHARM                                None
# 3       60 CAKE CASES VINTAGE CHRISTMAS                                None
# 4           60 TEATIME FAIRY CAKE CASES                                None
# ..                                  ...                                 ...
# 245      STRAWBERRY CERAMIC TRINKET BOX  WHITE HANGING HEART T-LIGHT HOLDER
# 246                  VINTAGE SNAP CARDS  VINTAGE HEADS AND TAILS CARD GAME
# 247         WOODEN FRAME ANTIQUE WHITE   WHITE HANGING HEART T-LIGHT HOLDER
# 248   WOODEN PICTURE FRAME WHITE FINISH  WHITE HANGING HEART T-LIGHT HOLDER
# 249   WOODEN PICTURE FRAME WHITE FINISH         WOODEN FRAME ANTIQUE WHITE
#
#       support  Confidance  lift
# 0    0.023244    0.023244   1.0
# 1    0.021131    0.021131   1.0
# 2    0.039256    0.039256   1.0
# 3    0.022164    0.022164   1.0
# 4    0.062735    0.062735   1.0
# ..        ...         ...   ...
# 245  0.025216    0.025216   1.0
# 246  0.020849    0.020849   1.0
# 247  0.024981    0.024981   1.0
# 248  0.021459    0.021459   1.0
# 249  0.028409    0.028409   1.0
#
# [250 rows x 5 columns]

# %%
df_final.fillna(value=' ', inplace=True)
df_final.head()
# Out:
#                                     0  1   support  Confidance  lift
# 0         12 PENCILS SMALL TUBE SKULL     0.023244    0.023244   1.0
# 1  3 HEARTS HANGING DECORATION RUSTIC     0.021131    0.021131   1.0
# 2              6 RIBBONS RUSTIC CHARM     0.039256    0.039256   1.0
# 3     60 CAKE CASES VINTAGE CHRISTMAS     0.022164    0.022164   1.0
# 4         60 TEATIME FAIRY CAKE CASES     0.062735    0.062735   1.0

# %%
#set column name
df_final.columns = ['lhs', 'rhs', 'support', 'confidance', 'lift']
df_final.head()
# Out:
#                                   lhs rhs   support  confidance  lift
# 0         12 PENCILS SMALL TUBE SKULL      0.023244    0.023244   1.0
# 1  3 HEARTS HANGING DECORATION RUSTIC      0.021131    0.021131   1.0
# 2              6 RIBBONS RUSTIC CHARM      0.039256    0.039256   1.0
# 3     60 CAKE CASES VINTAGE CHRISTMAS      0.022164    0.022164   1.0
# 4         60 TEATIME FAIRY CAKE CASES      0.062735    0.062735   1.0

# %%
# add all three column to lhs itemset only
df_final['lhs'] = df_final['lhs'] + ", " + df_final['rhs']

# rhs already contains the correct values, no need to concatenate further

# %%
df_final.head()
# Out:
#                                      lhs rhs   support  confidance  lift
# 0         12 PENCILS SMALL TUBE SKULL,        0.023244    0.023244   1.0
# 1  3 HEARTS HANGING DECORATION RUSTIC,        0.021131    0.021131   1.0
# 2              6 RIBBONS RUSTIC CHARM,        0.039256    0.039256   1.0
# 3     60 CAKE CASES VINTAGE CHRISTMAS,        0.022164    0.022164   1.0
# 4         60 TEATIME FAIRY CAKE CASES,        0.062735    0.062735   1.0

# %%
# Check if columns 'rhs', 'confidance', and 'lift' exist before dropping them
columns_to_drop = ['rhs', 'confidance', 'lift']
df_final.drop(columns=[col for col in columns_to_drop if col in df_final.columns], inplace=True)

# %%
#this is final output. You can sort based on the support lift and confidance..
df_final.head()
# Out:
#                                      lhs   support
# 0         12 PENCILS SMALL TUBE SKULL,    0.023244
# 1  3 HEARTS HANGING DECORATION RUSTIC,    0.021131
# 2              6 RIBBONS RUSTIC CHARM,    0.039256
# 3     60 CAKE CASES VINTAGE CHRISTMAS,    0.022164
# 4         60 TEATIME FAIRY CAKE CASES,    0.062735

# %%
## Showing top 10 items, based on lift.  Sorting in desc order
df_final.sort_values('lift', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 ## Showing top 10 items, based on lift.  Sorting in desc order
# ----> 2 df_final.sort_values('lift', ascending=False).head(10)
#
# NameError: name 'df_final' is not defined
